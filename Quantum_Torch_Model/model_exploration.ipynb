# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv('model_training_log.csv')

# %%
df
# Out:
#               model_name                                            savedir  \
# 0            samplemodel         models_saved/samplemodel__l0.1bs100ne1.pth
# 1           samplemodel2        models_saved/samplemodel2__l0.1bs100ne1.pth
# 2   Model_Type_2_LRTests  models_saved/Model_Type_2_LRTests__l0.0001bs10...
# 3   Model_Type_2_LRTests  models_saved/Model_Type_2_LRTests__l0.1bs100ne...
# 4   Model_Type_2_LRTests  models_saved/Model_Type_2_LRTests__l0.001bs100...
# 5   Model_Type_2_LRTests  models_saved/Model_Type_2_LRTests__l1.0bs100ne...
# 6   Model_Type_2_LRTests  models_saved/Model_Type_2_LRTests__l0.01bs100n...
# 7   Model_Type_2_BSTests  models_saved/Model_Type_2_BSTests__l0.0001bs10...
# 8   Model_Type_2_BSTests  models_saved/Model_Type_2_BSTests__l0.0001bs10...
# 9   Model_Type_2_BSTests  models_saved/Model_Type_2_BSTests__l0.0001bs10...
# 10  Model_Type_2_BSTests  models_saved/Model_Type_2_BSTests__l0.0001bs1n...
#
# ...
